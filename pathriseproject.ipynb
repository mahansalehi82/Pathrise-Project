# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression
#from sklearn.metrics import mean_absolute_error
import pickle
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_csv('Data_Pathrise.csv')

# %%
nulls = df.isnull().sum()

nulls = nulls[nulls > 0]
nulls.sort_values(inplace=True)
nulls = (nulls / ([len(df)] * 11))


ax = nulls.plot.bar(figsize = (15,10))
ax.set_ylabel("nulls%")
ax.set_xlabel('Variable Name')
# Out:
# Text(0.5, 0, 'Variable Name')

# %%
df = df[df['program_duration_days'] > 14]

# %%
df.drop(columns=['id','pathrise_status','cohort_tag'], axis=1, inplace=True)

# %%
df
# Out:
#      primary_track  program_duration_days  placed  employment_status   \
# 3              SWE                   89.0       1          Unemployed
# 6              SWE                   19.0       0  Employed Part-Time
# 10            Data                  158.0       0          Unemployed
# 12             PSO                   52.0       0  Employed Part-Time
# 21             SWE                   93.0       0          Contractor
# ...            ...                    ...     ...                 ...
# 2532           SWE                  119.0       1  Employed Full-Time
# 2536           SWE                  118.0       0  Employed Part-Time
# 2537        Design                  457.0       0          Contractor
# 2538          Data                  488.0       0                 NaN
# 2541           SWE                  285.0       0             Student
#
#      highest_level_of_education length_of_job_search  \
# 3             Bachelor's Degree           1-2 months
# 6             Bachelor's Degree  Less than one month
# 10              Master's Degree           3-5 months
# 12            Bachelor's Degree           1-2 months
# 21            Bachelor's Degree   6 months to a year
# ...                         ...                  ...
# 2532          Bachelor's Degree           1-2 months
# 2536            Master's Degree  Less than one month
# 2537            Master's Degree   6 months to a year
# 2538            Master's Degree           3-5 months
# 2541            Master's Degree           1-2 months
#
#               biggest_challenge_in_search professional_experience  \
# 3         Hearing back on my applications               1-2 years
# 6     Getting past final round interviews               1-2 years
# 10            Lack of relevant experience                5+ years
# 12            Lack of relevant experience      Less than one year
# 21        Hearing back on my applications               1-2 years
# ...                                   ...                     ...
# 2532           Getting past phone screens               1-2 years
# 2536          Lack of relevant experience                5+ years
# 2537               Technical interviewing                5+ years
# 2538      Hearing back on my applications               1-2 years
# 2541      Hearing back on my applications               1-2 years
#
#      work_authorization_status  number_of_interviews  number_of_applications  \
# 3                  F1 Visa/OPT                  10.0                     100
# 6                      Citizen                   4.0                      15
# 10                     Citizen                   5.0                      50
# 12                     Citizen                   4.0                      40
# 21                     Citizen                   1.0                      10
# ...                        ...                   ...                     ...
# 2532                   Citizen                   0.0                      10
# 2536                     Other                   1.0                      25
# 2537                   Citizen                   4.0                      15
# 2538               F1 Visa/OPT                   1.0                       7
# 2541                Green Card                   3.0                      70
#
#                         gender                                 race
# 3                         Male         East Asian or Asian American
# 6                       Female          Latino or Hispanic American
# 10                        Male             Decline to Self Identify
# 12                        Male  Non-Hispanic White or Euro-American
# 21                      Female         East Asian or Asian American
# ...                        ...                                  ...
# 2532                      Male       South Asian or Indian American
# 2536  Decline to Self Identify      Middle Eastern or Arab American
# 2537                      Male  Non-Hispanic White or Euro-American
# 2538                      Male  Non-Hispanic White or Euro-American
# 2541                      Male  Non-Hispanic White or Euro-American
#
# [1440 rows x 13 columns]

# %%
df_grouped = (df.groupby('placed')['gender'].value_counts(normalize=True).unstack('placed').plot.bar(stacked=False))

# %%
#'pathrise_status',
df_dummies = pd.get_dummies(data=df,columns=['primary_track','employment_status ','highest_level_of_education','length_of_job_search',
'biggest_challenge_in_search','professional_experience','work_authorization_status','gender','race'])

# %%
# cohorts = df["cohort_tag"].unique()
# cohorts = cohorts[0 : len(cohorts) - 1]
# cohorts.sort()
# chdic  = {}
# success = {}
# for i in cohorts:
#     chdic[i] = df[df["cohort_tag"] == i]
#     if(len(chdic[i]) != 0):
#         placed = chdic[i][chdic[i]["placed"] == 1]
#         success[i] = len(placed) / len(chdic[i])
#         #print(i, "  ", success[i], end="\t")
# plt.figure(figsize=(20,12))
# plt.bar(range(len(success)), list(success.values()), align='center',)
# plt.xticks(range(len(success)), list(success.keys()), rotation = 90)
# #plt.figure(figsize = (30,30))

# plt.show()

# %%
nulls = df.isnull().sum()
nulls = nulls[nulls > 0]
nulls.sort_values(inplace=True)
nulls = ((nulls / (len(df)) * 100))
ax = nulls.plot.bar(figsize = (10,7))
ax.set_ylabel("nulls%")
ax.set_xlabel('Variable Name')
# Out:
# Text(0.5, 0, 'Variable Name')

# %%
df_dummies.fillna(1, inplace=True)

# %%
dfc = df_dummies.copy()
df_dummies.drop(columns=["program_duration_days"], axis=1, inplace=True)
X = df_dummies.drop(columns=['placed'])

# %%
Y = df_dummies['placed']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state = 2711)

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X_train, Y_train)
# Out:
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = logreg.predict(X_test)

# %%
accuracy_score(Y_test, predictions)
# Out:
# 0.5995370370370371

# %%
confusion_matrix(Y_test,predictions)
# Out:
# array([[ 16, 151],
#        [ 22, 243]], dtype=int64)

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
prediction_knn = knn.predict(X_test)

# %%
accuracy_score(Y_test, prediction_knn)
# Out:
# 0.5740740740740741

# %%
confusion_matrix(Y_test,prediction_knn)
# Out:
# array([[ 28, 139],
#        [ 45, 220]], dtype=int64)

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(X_train , Y_train)
# Out:
# DecisionTreeClassifier()

# %%
predict_tree = tree.predict(X_test)

# %%
accuracy_score(Y_test, predict_tree)
# Out:
# 0.5416666666666666

# %%
confusion_matrix(Y_test,predict_tree)
# Out:
# array([[ 62, 105],
#        [ 93, 172]], dtype=int64)

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rf = rf.predict(X_test)

# %%
accuracy_score(Y_test, predict_rf)
# Out:
# 0.6018518518518519

# %%
confusion_matrix(Y_test,predict_rf)
# Out:
# array([[ 14, 153],
#        [ 19, 246]], dtype=int64)

# %%
confusion_matrix(Y_test,prediction_knn)
# Out:
# array([[ 28, 139],
#        [ 45, 220]], dtype=int64)

# %%
confusion_matrix(Y_test,predict_tree)
# Out:
# array([[ 62, 105],
#        [ 93, 172]], dtype=int64)

# %%
confusion_matrix(Y_test,predict_rf)
# Out:
# array([[ 14, 153],
#        [ 19, 246]], dtype=int64)

# %%
dfc = dfc[dfc["placed"] == 1]
dfc
# Out:
#       program_duration_days  placed  number_of_interviews  \
# 3                      89.0       1                  10.0
# 22                    193.0       1                   5.0
# 29                     73.0       1                   0.0
# 38                     83.0       1                   1.0
# 53                     76.0       1                   0.0
# ...                     ...     ...                   ...
# 2525                   31.0       1                   6.0
# 2526                  277.0       1                   1.0
# 2529                  310.0       1                   0.0
# 2531                   33.0       1                   0.0
# 2532                  119.0       1                   0.0
#
#       number_of_applications  primary_track_Data  primary_track_Design  \
# 3                        100                   0                     0
# 22                         4                   0                     0
# 29                         1                   0                     0
# 38                        15                   0                     0
# 53                        30                   0                     0
# ...                      ...                 ...                   ...
# 2525                       6                   0                     0
# 2526                      45                   0                     1
# 2529                       6                   0                     0
# 2531                       9                   0                     1
# 2532                      10                   0                     0
#
#       primary_track_Marketing  primary_track_PSO  primary_track_SWE  \
# 3                           0                  0                  1
# 22                          0                  1                  0
# 29                          0                  0                  1
# 38                          0                  0                  1
# 53                          0                  0                  1
# ...                       ...                ...                ...
# 2525                        0                  0                  1
# 2526                        0                  0                  0
# 2529                        0                  0                  1
# 2531                        0                  0                  0
# 2532                        0                  0                  1
#
#       primary_track_Web  ...  gender_Non-Binary  \
# 3                     0  ...                  0
# 22                    0  ...                  0
# 29                    0  ...                  0
# 38                    0  ...                  0
# 53                    0  ...                  0
# ...                 ...  ...                ...
# 2525                  0  ...                  0
# 2526                  0  ...                  0
# 2529                  0  ...                  0
# 2531                  0  ...                  0
# 2532                  0  ...                  0
#
#       race_Black, Afro-Caribbean, or African American  \
# 3                                                   0
# 22                                                  0
# 29                                                  0
# 38                                                  0
# 53                                                  0
# ...                                               ...
# 2525                                                0
# 2526                                                0
# 2529                                                0
# 2531                                                0
# 2532                                                0
#
#       race_Decline to Self Identify  race_East Asian or Asian American  \
# 3                                 0                                  1
# 22                                0                                  0
# 29                                0                                  1
# 38                                0                                  0
# 53                                0                                  1
# ...                             ...                                ...
# 2525                              0                                  0
# 2526                              1                                  0
# 2529                              0                                  1
# 2531                              0                                  0
# 2532                              0                                  0
#
#       race_Latino or Hispanic American  race_Middle Eastern or Arab American  \
# 3                                    0                                     0
# 22                                   0                                     0
# 29                                   0                                     0
# 38                                   0                                     0
# 53                                   0                                     0
# ...                                ...                                   ...
# 2525                                 0                                     0
# 2526                                 0                                     0
# 2529                                 0                                     0
# 2531                                 0                                     0
# 2532                                 0                                     0
#
#       race_Native American or Alaskan Native  \
# 3                                          0
# 22                                         0
# 29                                         0
# 38                                         1
# 53                                         0
# ...                                      ...
# 2525                                       0
# 2526                                       0
# 2529                                       0
# 2531                                       0
# 2532                                       0
#
#       race_Non-Hispanic White or Euro-American  \
# 3                                            0
# 22                                           1
# 29                                           0
# 38                                           0
# 53                                           0
# ...                                        ...
# 2525                                         0
# 2526                                         0
# 2529                                         0
# 2531                                         1
# 2532                                         0
#
#       race_South Asian or Indian American  race_Two or More Races
# 3                                       0                       0
# 22                                      0                       0
# 29                                      0                       0
# 38                                      0                       0
# 53                                      0                       0
# ...                                   ...                     ...
# 2525                                    1                       0
# 2526                                    0                       0
# 2529                                    0                       0
# 2531                                    0                       0
# 2532                                    1                       0
#
# [932 rows x 63 columns]

# %%
X = dfc.drop(columns=['program_duration_days'])
X
# Out:
#       placed  number_of_interviews  number_of_applications  \
# 3          1                  10.0                     100
# 22         1                   5.0                       4
# 29         1                   0.0                       1
# 38         1                   1.0                      15
# 53         1                   0.0                      30
# ...      ...                   ...                     ...
# 2525       1                   6.0                       6
# 2526       1                   1.0                      45
# 2529       1                   0.0                       6
# 2531       1                   0.0                       9
# 2532       1                   0.0                      10
#
#       primary_track_Data  primary_track_Design  primary_track_Marketing  \
# 3                      0                     0                        0
# 22                     0                     0                        0
# 29                     0                     0                        0
# 38                     0                     0                        0
# 53                     0                     0                        0
# ...                  ...                   ...                      ...
# 2525                   0                     0                        0
# 2526                   0                     1                        0
# 2529                   0                     0                        0
# 2531                   0                     1                        0
# 2532                   0                     0                        0
#
#       primary_track_PSO  primary_track_SWE  primary_track_Web  \
# 3                     0                  1                  0
# 22                    1                  0                  0
# 29                    0                  1                  0
# 38                    0                  1                  0
# 53                    0                  1                  0
# ...                 ...                ...                ...
# 2525                  0                  1                  0
# 2526                  0                  0                  0
# 2529                  0                  1                  0
# 2531                  0                  0                  0
# 2532                  0                  1                  0
#
#       employment_status _Contractor  ...  gender_Non-Binary  \
# 3                                 0  ...                  0
# 22                                0  ...                  0
# 29                                0  ...                  0
# 38                                0  ...                  0
# 53                                0  ...                  0
# ...                             ...  ...                ...
# 2525                              0  ...                  0
# 2526                              0  ...                  0
# 2529                              0  ...                  0
# 2531                              0  ...                  0
# 2532                              0  ...                  0
#
#       race_Black, Afro-Caribbean, or African American  \
# 3                                                   0
# 22                                                  0
# 29                                                  0
# 38                                                  0
# 53                                                  0
# ...                                               ...
# 2525                                                0
# 2526                                                0
# 2529                                                0
# 2531                                                0
# 2532                                                0
#
#       race_Decline to Self Identify  race_East Asian or Asian American  \
# 3                                 0                                  1
# 22                                0                                  0
# 29                                0                                  1
# 38                                0                                  0
# 53                                0                                  1
# ...                             ...                                ...
# 2525                              0                                  0
# 2526                              1                                  0
# 2529                              0                                  1
# 2531                              0                                  0
# 2532                              0                                  0
#
#       race_Latino or Hispanic American  race_Middle Eastern or Arab American  \
# 3                                    0                                     0
# 22                                   0                                     0
# 29                                   0                                     0
# 38                                   0                                     0
# 53                                   0                                     0
# ...                                ...                                   ...
# 2525                                 0                                     0
# 2526                                 0                                     0
# 2529                                 0                                     0
# 2531                                 0                                     0
# 2532                                 0                                     0
#
#       race_Native American or Alaskan Native  \
# 3                                          0
# 22                                         0
# 29                                         0
# 38                                         1
# 53                                         0
# ...                                      ...
# 2525                                       0
# 2526                                       0
# 2529                                       0
# 2531                                       0
# 2532                                       0
#
#       race_Non-Hispanic White or Euro-American  \
# 3                                            0
# 22                                           1
# 29                                           0
# 38                                           0
# 53                                           0
# ...                                        ...
# 2525                                         0
# 2526                                         0
# 2529                                         0
# 2531                                         1
# 2532                                         0
#
#       race_South Asian or Indian American  race_Two or More Races
# 3                                       0                       0
# 22                                      0                       0
# 29                                      0                       0
# 38                                      0                       0
# 53                                      0                       0
# ...                                   ...                     ...
# 2525                                    1                       0
# 2526                                    0                       0
# 2529                                    0                       0
# 2531                                    0                       0
# 2532                                    1                       0
#
# [932 rows x 62 columns]

# %%
Y = dfc['program_duration_days']
dfc
# Out:
#       program_duration_days  placed  number_of_interviews  \
# 3                      89.0       1                  10.0
# 22                    193.0       1                   5.0
# 29                     73.0       1                   0.0
# 38                     83.0       1                   1.0
# 53                     76.0       1                   0.0
# ...                     ...     ...                   ...
# 2525                   31.0       1                   6.0
# 2526                  277.0       1                   1.0
# 2529                  310.0       1                   0.0
# 2531                   33.0       1                   0.0
# 2532                  119.0       1                   0.0
#
#       number_of_applications  primary_track_Data  primary_track_Design  \
# 3                        100                   0                     0
# 22                         4                   0                     0
# 29                         1                   0                     0
# 38                        15                   0                     0
# 53                        30                   0                     0
# ...                      ...                 ...                   ...
# 2525                       6                   0                     0
# 2526                      45                   0                     1
# 2529                       6                   0                     0
# 2531                       9                   0                     1
# 2532                      10                   0                     0
#
#       primary_track_Marketing  primary_track_PSO  primary_track_SWE  \
# 3                           0                  0                  1
# 22                          0                  1                  0
# 29                          0                  0                  1
# 38                          0                  0                  1
# 53                          0                  0                  1
# ...                       ...                ...                ...
# 2525                        0                  0                  1
# 2526                        0                  0                  0
# 2529                        0                  0                  1
# 2531                        0                  0                  0
# 2532                        0                  0                  1
#
#       primary_track_Web  ...  gender_Non-Binary  \
# 3                     0  ...                  0
# 22                    0  ...                  0
# 29                    0  ...                  0
# 38                    0  ...                  0
# 53                    0  ...                  0
# ...                 ...  ...                ...
# 2525                  0  ...                  0
# 2526                  0  ...                  0
# 2529                  0  ...                  0
# 2531                  0  ...                  0
# 2532                  0  ...                  0
#
#       race_Black, Afro-Caribbean, or African American  \
# 3                                                   0
# 22                                                  0
# 29                                                  0
# 38                                                  0
# 53                                                  0
# ...                                               ...
# 2525                                                0
# 2526                                                0
# 2529                                                0
# 2531                                                0
# 2532                                                0
#
#       race_Decline to Self Identify  race_East Asian or Asian American  \
